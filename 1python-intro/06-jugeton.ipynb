# %% [markdown]
# # **Codig Dojo**: Reto grupal jugeton
# ## Creado por: Alejandro Acosta
#
# - Fecha de creación: 2022-01-10
# - Fecha de modificación: 2022-01-12
# - Descripción: Base de datos de clientes potenciales

# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_csv('act_1.csv', sep=';')
df2 = pd.read_csv('act_2.csv', sep=';')
df3 = pd.read_csv('act_3.csv', sep=';')

# %%
df1[df1.desc=='Encantados']
# Out:
#        Unnamed: 0  CustomerID  NumberCarsOwned  NumberChildrenAtHome  \
# 1               2       13249                2                     1
# 3               4       13503                2                     1
# 5               6       22092                2                     2
# 12             13       20029                1                     1
# 16             17       17127                3                     1
# ...           ...         ...              ...                   ...
# 18322       18323       14248                1                     1
# 18331       18332       23028                0                     1
# 18336       18337       25869                1                     2
# 18340       18341       14751                2                     1
# 18343       18344       11465                1                     1
#
#        TotalChildren  YearlyIncome  AvgMonthSpend  cluster        desc
# 1                  2       81076.0          53.11        4  Encantados
# 3                  2       61481.0          56.93        4  Encantados
# 5                  2       61944.0          49.31        4  Encantados
# 12                 2      108198.0          52.66        4  Encantados
# 16                 1       79019.0          50.48        4  Encantados
# ...              ...           ...            ...      ...         ...
# 18322              2           0.0          51.84        4  Encantados
# 18331              1           0.0          52.61        4  Encantados
# 18336              2           0.0          51.30        4  Encantados
# 18340              2           0.0          50.30        4  Encantados
# 18343              1           0.0          54.44        4  Encantados
#
# [3048 rows x 9 columns]

# %%
df2[df2.desc=='Encantados']
# Out:
#        Unnamed: 0  CustomerID  NumberCarsOwned  NumberChildrenAtHome  \
# 1               2       13249                2                     1
# 3               4       13503                2                     1
# 5               6       22092                2                     2
# 12             13       20029                1                     1
# 16             17       17127                3                     1
# ...           ...         ...              ...                   ...
# 18322       18323       14248                1                     1
# 18331       18332       23028                0                     1
# 18336       18337       25869                1                     2
# 18340       18341       14751                2                     1
# 18343       18344       11465                1                     1
#
#        TotalChildren  YearlyIncome  AvgMonthSpend  cluster        desc
# 1                  2         81076          53.11        4  Encantados
# 3                  2         61481          56.93        4  Encantados
# 5                  2         61944          49.31        4  Encantados
# 12                 2        108198          52.66        4  Encantados
# 16                 1         79019          50.48        4  Encantados
# ...              ...           ...            ...      ...         ...
# 18322              2        136686          51.84        4  Encantados
# 18331              1        109415          52.61        4  Encantados
# 18336              2         59026          51.30        4  Encantados
# 18340              2         80483          50.30        4  Encantados
# 18343              1         85747          54.44        4  Encantados
#
# [3048 rows x 9 columns]

# %%
df3[df3.desc=='Encantados']
# Out:
#        Unnamed: 0  CustomerID  NumberCarsOwned  TotalChildren  YearlyIncome  \
# 1               2       13249                2             -2         81076
# 3               4       13503                2             -2         61481
# 5               6       22092                2             -2         61944
# 12             13       20029                1             -2        108198
# 16             17       17127                3             -1         79019
# ...           ...         ...              ...            ...           ...
# 18322       18323       14248                1             -2        136686
# 18331       18332       23028                0             -1        109415
# 18336       18337       25869                1             -2         59026
# 18340       18341       14751                2             -2         80483
# 18343       18344       11465                1             -1         85747
#
#       AvgMonthSpend  cluster        desc Toys_interested location
# 1             53,11        4  Encantados              si    norte
# 3             56,93        4  Encantados              si    norte
# 5             49,31        4  Encantados              no    norte
# 12              NaN        4  Encantados              no    norte
# 16              NaN        4  Encantados              no    norte
# ...             ...      ...         ...             ...      ...
# 18322         51,84        4  Encantados              no   centro
# 18331         52,61        4  Encantados              no   centro
# 18336          51,3        4  Encantados              no   centro
# 18340          50,3        4  Encantados              no   centro
# 18343         54,44        4  Encantados              no   centro
#
# [3048 rows x 10 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18355 entries, 0 to 18354
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            18355 non-null  int64
#  1   CustomerID            18355 non-null  int64
#  2   NumberCarsOwned       18355 non-null  int64
#  3   NumberChildrenAtHome  18355 non-null  int64
#  4   TotalChildren         18355 non-null  int64
#  5   YearlyIncome          10409 non-null  float64
#  6   AvgMonthSpend         18355 non-null  float64
#  7   cluster               18355 non-null  int64
#  8   desc                  18355 non-null  object
# dtypes: float64(2), int64(6), object(1)
# memory usage: 1.3+ MB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18355 entries, 0 to 18354
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            18355 non-null  int64
#  1   CustomerID            18355 non-null  int64
#  2   NumberCarsOwned       18355 non-null  int64
#  3   NumberChildrenAtHome  18355 non-null  int64
#  4   TotalChildren         18355 non-null  int64
#  5   YearlyIncome          18355 non-null  int64
#  6   AvgMonthSpend         18355 non-null  float64
#  7   cluster               18355 non-null  int64
#  8   desc                  18355 non-null  object
# dtypes: float64(1), int64(7), object(1)
# memory usage: 1.3+ MB

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18355 entries, 0 to 18354
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       18355 non-null  int64
#  1   CustomerID       18355 non-null  int64
#  2   NumberCarsOwned  18355 non-null  int64
#  3   TotalChildren    18355 non-null  int64
#  4   YearlyIncome     18355 non-null  int64
#  5   AvgMonthSpend    18339 non-null  object
#  6   cluster          18355 non-null  int64
#  7   desc             18355 non-null  object
#  8   Toys_interested  18355 non-null  object
#  9   location         18355 non-null  object
# dtypes: int64(6), object(4)
# memory usage: 1.4+ MB

# %%
df2.head()
# Out:
#        Unnamed: 0  CustomerID  NumberCarsOwned  NumberChildrenAtHome  \
# 18350       18351       25414                1                     0
# 18351       18352       11459                2                     0
# 18352       18353       12160                2                     0
# 18353       18354       14353                0                     0
# 18354       18355       16676                2                     0
#
#        TotalChildren  YearlyIncome  AvgMonthSpend  cluster           desc
# 18350              2         52953          48.14        3        Felices
# 18351              0         60992          50.23        1  Insatisfechos
# 18352              0         51859          49.56        1  Insatisfechos
# 18353              0         87177          51.42        1  Insatisfechos
# 18354              0        136856          52.27        2     Con quejas

# %%
df3.head()
# Out:
#    Unnamed: 0  CustomerID  NumberCarsOwned  TotalChildren  YearlyIncome  \
# 0           1       21173                3             -1         81916
# 1           2       13249                2             -2         81076
# 2           3       29350                3              0         86387
# 3           4       13503                2             -2         61481
# 4           5       22803                1              0         51804
#
#   AvgMonthSpend  cluster           desc Toys_interested location
# 0         50,97        2     Con quejas              si    norte
# 1         53,11        4     Encantados              si    norte
# 2         54,08        2     Con quejas              si    norte
# 3         56,93        4     Encantados              si    norte
# 4         55,41        1  Insatisfechos              no    norte

# %%
df = df2.merge(df3, how='inner', on='CustomerID')

# %%
df.shape
# Out:
# (18355, 18)

# %%
df2.YearlyIncome.hist()
# Out:
# <AxesSubplot:>

# %%
df3.YearlyIncome.hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# **Descripción del reto:** La empresa Juguetón contrata a Coding Dojo para una consultoría de ciencia de datos.
#
# * El gerente de mercadeo de Juguetón precide el proyecto e indica que el objetivo es encontrar la mejor ruta de marketing para el lanzamiento de su nuevo juguete "IG-NA".

# %% [markdown]
# *puedes continuar escribiendo en el primer notebook*

# %% [markdown]
# **Actividades**
# - Lee la base de datos: act_3
# - ¿Cuántos clientes dijeron estar Felices, encantados, insatisfechos o con quejas con el servicio?
# - ¿Cuántos clientes viven en la localidad del norte,sur y centro de la ciudad?
# - A Juguetón le interesa vender el producto en las dos localidad con mayor concetración de clientes.¿Qué localidades son?
#
# **Para cada una de las localidades**
#
# - ¿Existen valores faltantes?
# - La base final será presentada al equipo designado de Juguetón, deja solo las variables de interés.
# - Han recibido un correo del área de servicio al cliente donde indica:
#     "Hubo un error al digitar la variable *TotalChildren* y se le antepuso el signo (-), con la corrección pertinente la variable es de utilidad".
# Realiza el cambio necesario a dicha variable.
# - Se nos ha informado que el Gerente comercial espera que para la reunión se pueda tener una vista general de los clientes (por localidad) que dijeron estar "Felices" y "Encantados" para crear un plan de fidelización.
# Genera esta vista.
# - Han recibido otro correo del área comercial donde indica:
#   " Estimado equipo Coding Dojo, favor para la reunión de revisión de avances indicar una vista general de los clientes que dijeron estar "Felices" y "Encantados" y que ganan más de $80k anuales para invitarlos al lanzamiento del jueguete IG-NA".
#   Geenra esta vista.
# - Han vuelto a recibir un correo del área de servicio al cliente donde indica:
#   "Hemos estado revisando la base de datos que les enviaron y encontramos que la variable "Toy_interested" está mal etiquetada y en realidad hace referencia a si el cliente tiene o no la suscripción a nuestra newsletter, para que puedan hacer la corrección respectiva".
#   Corrige el nombre de la variable.
# -El area de seguridad de la informacion esta creando manuales donde se encriptan las identificaciones de los clientes, por lo que se nos solicita que por si acaso el Gerente de Seguridad de la Informacion este, no se muestre la variable CustomerID. En caso de que no asista si se puede seguir con la vista completa.
# Dejar comentada la linea donde se elimina esta variables para ejecutar solo si es necesario.
# - Siguiendo con nuestra exploración de la base de datos: elimina aquellas variables que tengan el 80% de valores faltantes.
# - Para aquellas variables que tengan valores perdidos pero sea menos del 80%, realiza una imputación "ffill".

# %%
df = pd.read_csv('act_3.csv', sep=';')

# %%
df.groupby('desc').count()['location']
# Out:
# desc
# Con quejas       5301
# Encantados       3048
# Felices          3879
# Insatisfechos    6127
# Name: location, dtype: int64

# %%
df['desc'].value_counts(dropna=False)
# Out:
# Insatisfechos    6127
# Con quejas       5301
# Felices          3879
# Encantados       3048
# Name: desc, dtype: int64

# %%
df['location'].value_counts(dropna=False)
# Out:
# centro    11825
# sur        6469
# norte        61
# Name: location, dtype: int64

# %%
dft = df.isna()
dft['location'] = df['location']

dft.groupby('location').sum()
# Out:
#           Unnamed: 0  CustomerID  NumberCarsOwned  TotalChildren  \
# location
# centro             0           0                0              0
# norte              0           0                0              0
# sur                0           0                0              0
#
#           YearlyIncome  AvgMonthSpend  cluster  desc  Toys_interested
# location
# centro               0              8        0     0                0
# norte                0              8        0     0                0
# sur                  0              0        0     0                0

# %%
df['TotalChildren'] = df.TotalChildren.abs()

# %%
df.drop('cluster', axis=1, inplace=True)

# %%
df.head()
# Out:
#    Unnamed: 0  CustomerID  NumberCarsOwned  TotalChildren  YearlyIncome  \
# 0           1       21173                3              1         81916
# 1           2       13249                2              2         81076
# 2           3       29350                3              0         86387
# 3           4       13503                2              2         61481
# 4           5       22803                1              0         51804
#
#   AvgMonthSpend           desc Toys_interested location
# 0         50,97     Con quejas              si    norte
# 1         53,11     Encantados              si    norte
# 2         54,08     Con quejas              si    norte
# 3         56,93     Encantados              si    norte
# 4         55,41  Insatisfechos              no    norte

# %%
df[df.desc.isin(['Felices','Encantados'])]
# Out:
#        Unnamed: 0  CustomerID  NumberCarsOwned  TotalChildren  YearlyIncome  \
# 1               2       13249                2              2         81076
# 3               4       13503                2              2         61481
# 5               6       22092                2              2         61944
# 8               9       12127                0              2         83834
# 12             13       20029                1              2        108198
# ...           ...         ...              ...            ...           ...
# 18343       18344       11465                1              1         85747
# 18344       18345       16011                1              2         87320
# 18348       18349       26722                0              2         29758
# 18349       18350       14522                1              2         30442
# 18350       18351       25414                1              2         52953
#
#       AvgMonthSpend        desc Toys_interested location
# 1             53,11  Encantados              si    norte
# 3             56,93  Encantados              si    norte
# 5             49,31  Encantados              no    norte
# 8             50,05     Felices              no    norte
# 12              NaN  Encantados              no    norte
# ...             ...         ...             ...      ...
# 18343         54,44  Encantados              no   centro
# 18344          50,1     Felices              no   centro
# 18348           NaN     Felices              no   centro
# 18349           NaN     Felices              no   centro
# 18350           NaN     Felices              no   centro
#
# [6927 rows x 9 columns]

# %%
df.rename(columns={'Toys_interested':'subscription'}, inplace=True)
# Out:
#        Unnamed: 0  CustomerID  NumberCarsOwned  TotalChildren  YearlyIncome  \
# 0               1       21173                3              1         81916
# 1               2       13249                2              2         81076
# 2               3       29350                3              0         86387
# 3               4       13503                2              2         61481
# 4               5       22803                1              0         51804
# ...           ...         ...              ...            ...           ...
# 18350       18351       25414                1              2         52953
# 18351       18352       11459                2              0         60992
# 18352       18353       12160                2              0         51859
# 18353       18354       14353                0              0         87177
# 18354       18355       16676                2              0        136856
#
#       AvgMonthSpend           desc subscription location
# 0             50,97     Con quejas           si    norte
# 1             53,11     Encantados           si    norte
# 2             54,08     Con quejas           si    norte
# 3             56,93     Encantados           si    norte
# 4             55,41  Insatisfechos           no    norte
# ...             ...            ...          ...      ...
# 18350           NaN        Felices           no   centro
# 18351           NaN  Insatisfechos           no   centro
# 18352           NaN  Insatisfechos           no   centro
# 18353           NaN  Insatisfechos           no   centro
# 18354           NaN     Con quejas           no   centro
#
# [18355 rows x 9 columns]
