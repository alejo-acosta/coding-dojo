# %% [markdown]
# # *Codig Dojo*: Segunda Clase
# ## Creado por: Alejandro Acosta
#
# - Fecha de creación: 2022-01-05
# - Fecha de modificación: 2022-01-05
# - Descripción: Organización de un notebook

# %%
import numpy as np
import pandas as pd

# %%
for i in range(1,21):
  if (i%3==0) & (i%5==0):
    print('fizzbuzz')
  elif i%3==0:
    print('fizz')
  elif i%5==0:
    print('buzz')
  else:
    print(i)
# Out:
# 1
# 2
# fizz
# 4
# buzz
# fizz
# 7
# 8
# fizz
# buzz
# 11
# fizz
# 13
# 14
# fizzbuzz
# 16
# 17
# fizz
# 19
# buzz

# %%
print(*map(lambda i: 'Fizz'*(not i%3)+'Buzz'*(not i%5) or i, range(1,21)),sep='\n')
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
