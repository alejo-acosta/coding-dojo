# %% [markdown]
# # *Codig Dojo*: ejercicio hipoteca
# ## Creado por: Alejandro Acosta
#
# - Fecha de creación: 2022-01-07
# - Fecha de modificación: 2022-01-07
# - Descripción: cálculo de cuotas de hipoteca

# %%
def cuotas(p, r, n):
  return p*(r*(1+r)**n)/((1+r)**n-1)

# %%
cuotas(400000, 0.03, 360)
# Out:
# 12000.286939763988
