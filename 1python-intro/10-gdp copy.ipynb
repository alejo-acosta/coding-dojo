# %% [markdown]
# # **Codig Dojo**: GDP
# ## Creado por: Alejandro Acosta
#
# - Fecha de creación: 2022-01-16
# - Fecha de modificación: 2022-01-16
# - Descripción: Ejercicio GDP

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('GDP.csv', header=2)
df.drop(['Unnamed: 62','Indicator Name', 'Indicator Code'], axis=1, inplace=True)

# %%
df.head()
# Out:
#   Country Name Country Code          1960          1961          1962  \
# 0        Aruba          ABW           NaN           NaN           NaN
# 1  Afghanistan          AFG  5.377778e+08  5.488889e+08  5.466667e+08
# 2       Angola          AGO           NaN           NaN           NaN
# 3      Albania          ALB           NaN           NaN           NaN
# 4      Andorra          AND           NaN           NaN           NaN
#
#            1963          1964          1965          1966          1967  ...  \
# 0           NaN           NaN           NaN           NaN           NaN  ...
# 1  7.511112e+08  8.000000e+08  1.006667e+09  1.400000e+09  1.673333e+09  ...
# 2           NaN           NaN           NaN           NaN           NaN  ...
# 3           NaN           NaN           NaN           NaN           NaN  ...
# 4           NaN           NaN           NaN           NaN           NaN  ...
#
#            2008          2009          2010          2011          2012  \
# ...

# %%
df.columns
# Out:
# Index(['Country Name', 'Country Code', '1960', '1961', '1962', '1963', '1964',
#        '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973',
#        '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982',
#        '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991',
#        '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000',
#        '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009',
#        '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017'],
#       dtype='object')

# %%
columnas = ['Country Name', 'Country Code']

df2 = df.melt(id_vars=columnas, var_name='Year', value_name='GDP').dropna().sort_values(['Country Code','Year'])

df2.head()
# Out:
#       Country Name Country Code  Year           GDP
# 8976         Aruba          ABW  1994  1.330168e+09
# 9240         Aruba          ABW  1995  1.320670e+09
# 9504         Aruba          ABW  1996  1.379888e+09
# 9768         Aruba          ABW  1997  1.531844e+09
# 10032        Aruba          ABW  1998  1.665363e+09
